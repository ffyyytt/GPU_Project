# %% [markdown]
# # General

# %%
# !nvidia-smi
# Out:
# Sun Dec 25 18:13:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 442.23       Driver Version: 411.31       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce MX130      WDDM  | 00000000:02:00.0 Off |                  N/A |
# | N/A   54C    P8    N/A / ERR! |     37MiB /  2048MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !.\make
# Out:
# (base) D:\CRYPTIS\GPU\GPU_Project\source>nvcc -o main main.cu ImageProcessorCPU.cpp ImageProcessorGPU.cu utils/image.cpp utils/chronoCPU.cpp utils/chronoGPU.cu
# main.cu
# ImageProcessorCPU.cpp
# main.cu(8): warning: conversion from a string literal to "char *" is deprecated
#
# main.cu(8): warning: conversion from a string literal to "char *" is deprecated
#
# main.cu(8): warning: conversion from a string literal to "char *" is deprecated
#
# main.cu(8): warning: conversion from a string literal to "char *" is deprecated
# ImageProcessorGPU.cu
# image.cpp
# chronoCPU.cpp
# chronoGPU.cu
#    Creating library main.lib and object main.exp

# %%
import os
import cv2
import math
import hashlib
import numpy as np
import matplotlib.pyplot as plt

from tqdm.notebook import *

plt.rcParams['figure.figsize'] = [15, 16]

# %%
def timeCapture(cmd, times = 1):
    return [float(os.popen(cmd).read().strip()) for i in range(times)]

# %%
def change_brightness(img, value=30):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)
    v = cv2.add(v,value)
    v[v > 255] = 255
    v[v < 0] = 0
    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

def readImage(file):
    return cv2.cvtColor(cv2.imread(file), cv2.COLOR_BGR2RGB)

def getVisualize(file, bins = list(range(257))):
    image = cv2.cvtColor(cv2.imread(file), cv2.COLOR_BGR2HSV)
    hist = np.histogram(image[:,:,2].flatten(), bins=bins)[0]
    x = np.array(bins[:-1])
    y = np.array([0.0]*len(x))
    for i in bins[:-1]:
        x[i] = i
        y[i] = y[i-1] + hist[i]
    y = y*max(hist)/max(y)
    
    return image[:,:,2].flatten(), (x, y)

# %%
image = cv2.cvtColor(cv2.imread("images/Lenna.png"), cv2.COLOR_BGR2RGB)
image_brightness = change_brightness(image, -120)
cv2.imwrite("images/Lenna_brightness.png", cv2.cvtColor(image_brightness, cv2.COLOR_RGB2BGR))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(image)
axarr[0].set_title("Origin Lenna")
axarr[0].axis('off')

axarr[1].imshow(image_brightness)
axarr[1].set_title("Lenna increase brightness")
axarr[1].axis('off')

plt.show()

# %% [markdown]
# # Check equal

# %% [markdown]
# ## MaxAbsScaler

# %%
os.popen("main images/Chateau.png images/Chateau_CPU_0.png 0 256 0 8 1 1 8 1 1").read()
os.popen("main images/Chateau.png images/Chateau_GPU_0.png 0 256 1 8 1 1 8 1 1").read()

os.popen("main images/palais_garnier.jpg images/palais_garnier_CPU_0.jpg 0 256 0 8 1 1 8 1 1").read()
os.popen("main images/palais_garnier.jpg images/palais_garnier_GPU_0.jpg 0 256 1 8 1 1 8 1 1").read()

print("Chateau_CPU:", hashlib.md5(open('images/Chateau_CPU_0.png','rb').read()).hexdigest())
print("Chateau_GPU:", hashlib.md5(open('images/Chateau_GPU_0.png','rb').read()).hexdigest())

print("palais_garnier_CPU:", hashlib.md5(open('images/palais_garnier_CPU_0.jpg','rb').read()).hexdigest())
print("palais_garnier_GPU:", hashlib.md5(open('images/palais_garnier_GPU_0.jpg','rb').read()).hexdigest())
# Out:
# Chateau_CPU: 7f698b2c308e2b3a4c2fb264f21360c7
# Chateau_GPU: 7f698b2c308e2b3a4c2fb264f21360c7
# palais_garnier_CPU: 8beee4e1cac3512c9ebb9f736b8e4a52
# palais_garnier_GPU: 8beee4e1cac3512c9ebb9f736b8e4a52

# %% [markdown]
# ## MinMaxScaler

# %%
os.popen("main images/Chateau.png images/Chateau_CPU_1.png 1 256 0 8 1 1 8 1 1").read()
os.popen("main images/Chateau.png images/Chateau_GPU_1.png 1 256 1 8 1 1 8 1 1").read()

os.popen("main images/palais_garnier.jpg images/palais_garnier_CPU_1.jpg 1 256 0 8 1 1 8 1 1").read()
os.popen("main images/palais_garnier.jpg images/palais_garnier_GPU_1.jpg 1 256 1 8 1 1 8 1 1").read()

print("Chateau_CPU:", hashlib.md5(open('images/Chateau_CPU_1.png','rb').read()).hexdigest())
print("Chateau_GPU:", hashlib.md5(open('images/Chateau_GPU_1.png','rb').read()).hexdigest())

print("palais_garnier_CPU:", hashlib.md5(open('images/palais_garnier_CPU_1.jpg','rb').read()).hexdigest())
print("palais_garnier_GPU:", hashlib.md5(open('images/palais_garnier_GPU_1.jpg','rb').read()).hexdigest())
# Out:
# Chateau_CPU: 7f698b2c308e2b3a4c2fb264f21360c7
# Chateau_GPU: 7f698b2c308e2b3a4c2fb264f21360c7
# palais_garnier_CPU: 23baaefcdc8477db735f9990630b5abc
# palais_garnier_GPU: 23baaefcdc8477db735f9990630b5abc

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Chateau

# %%
file = "images/Chateau.png"
fileMax = "images/Chateau_GPU_0.png"
fileMin = "images/Chateau_GPU_1.png"
plt.figure()
f, axarr = plt.subplots(2,3)

image = readImage(file)
axarr[0, 0].imshow(image)
axarr[0, 0].axis('off')
axarr[0, 0].set_title("Original image")

imageMax = readImage(fileMax)
axarr[0, 1].imshow(imageMax)
axarr[0, 1].axis('off')
axarr[0, 1].set_title("Image MaxAbsScaler")

imageMin = readImage(fileMin)
axarr[0, 2].imshow(imageMin)
axarr[0, 2].axis('off')
axarr[0, 2].set_title("Image MinMaxScaler")


vis = getVisualize(file)
axarr[1, 0].plot(vis[1][0], vis[1][1], color = 'red')
axarr[1, 0].hist(vis[0], bins=256, color = 'blue')
axarr[1, 0].set_title("Histogram original")

visMax = getVisualize(fileMax)
axarr[1, 1].plot(visMax[1][0], visMax[1][1], color = 'red')
axarr[1, 1].hist(visMax[0], bins=256, color = 'blue')
axarr[1, 1].set_title("Histogram MaxAbsScaler")

visMin = getVisualize(fileMin)
axarr[1, 2].plot(visMin[1][0], visMin[1][1], color = 'red')
axarr[1, 2].hist(visMin[0], bins=256, color = 'blue')
axarr[1, 2].set_title("Histogram MinMaxScaler")

plt.show()

# %% [markdown]
# ## palais garnier

# %%
file = "images/palais_garnier.jpg"
fileMax = "images/palais_garnier_GPU_0.jpg"
fileMin = "images/palais_garnier_GPU_1.jpg"
plt.figure()
f, axarr = plt.subplots(2,3)

image = readImage(file)
axarr[0, 0].imshow(image)
axarr[0, 0].axis('off')
axarr[0, 0].set_title("Original image")

imageMax = readImage(fileMax)
axarr[0, 1].imshow(imageMax)
axarr[0, 1].axis('off')
axarr[0, 1].set_title("Image MaxAbsScaler")

imageMin = readImage(fileMin)
axarr[0, 2].imshow(imageMin)
axarr[0, 2].axis('off')
axarr[0, 2].set_title("Image MinMaxScaler")


vis = getVisualize(file)
axarr[1, 0].plot(vis[1][0], vis[1][1], color = 'red')
axarr[1, 0].hist(vis[0], bins=256, color = 'blue')
axarr[1, 0].set_title("Histogram original")

visMax = getVisualize(fileMax)
axarr[1, 1].plot(visMax[1][0], visMax[1][1], color = 'red')
axarr[1, 1].hist(visMax[0], bins=256, color = 'blue')
axarr[1, 1].set_title("Histogram MaxAbsScaler")

visMin = getVisualize(fileMin)
axarr[1, 2].plot(visMin[1][0], visMin[1][1], color = 'red')
axarr[1, 2].hist(visMin[0], bins=256, color = 'blue')
axarr[1, 2].set_title("Histogram MinMaxScaler")

plt.show()

# %% [markdown]
# ## Lenna

# %%
os.popen("main images/Lenna_brightness.png images/Lenna_brightness_GPU_0.png 0 256 1 2 8 2 1 8 2").read()
os.popen("main images/Lenna_brightness.png images/Lenna_brightness_GPU_1.png 1 256 1 2 8 2 1 8 2").read()
# Out:
# '5.39418\n'

# %%
file = "images/Lenna_brightness.png"
fileMax = "images/Lenna_brightness_GPU_0.png"
fileMin = "images/Lenna_brightness_GPU_1.png"
plt.figure()
f, axarr = plt.subplots(2,3)

image = readImage(file)
axarr[0, 0].imshow(image)
axarr[0, 0].axis('off')
axarr[0, 0].set_title("Original image")

imageMax = readImage(fileMax)
axarr[0, 1].imshow(imageMax)
axarr[0, 1].axis('off')
axarr[0, 1].set_title("Image MaxAbsScaler")

imageMin = readImage(fileMin)
axarr[0, 2].imshow(imageMin)
axarr[0, 2].axis('off')
axarr[0, 2].set_title("Image MinMaxScaler")


vis = getVisualize(file)
axarr[1, 0].plot(vis[1][0], vis[1][1], color = 'red')
axarr[1, 0].hist(vis[0], bins=256, color = 'blue')
axarr[1, 0].set_title("Histogram original")

visMax = getVisualize(fileMax)
axarr[1, 1].plot(visMax[1][0], visMax[1][1], color = 'red')
axarr[1, 1].hist(visMax[0], bins=256, color = 'blue')
axarr[1, 1].set_title("Histogram MaxAbsScaler")

visMin = getVisualize(fileMin)
axarr[1, 2].plot(visMin[1][0], visMin[1][1], color = 'red')
axarr[1, 2].hist(visMin[0], bins=256, color = 'blue')
axarr[1, 2].set_title("Histogram MinMaxScaler")

plt.show()

# %%
thread_time = {}
times = 2
for gridDimx in [0, 5, 10]:
    for gridDimy in [0]:
        for gridDimz in [0, 4]:
            for blockDimx in [0, 3]:
                for blockDimy in [0, 2]:
                    for blockDimz in [0, 3]:
                        cmd = f"main images/Chateau.png images/temp.png 1 256 1 {2**gridDimx} {2**gridDimy} {2**gridDimz} {2**blockDimx} {2**blockDimy} {2**blockDimz}"
                        result = timeCapture(cmd, times)
                        print("Command:", cmd, "Time:", result)
                        if (gridDimx+gridDimy+gridDimz+blockDimx+blockDimy+blockDimz) in thread_time:
                            thread_time[(gridDimx+gridDimy+gridDimz+blockDimx+blockDimy+blockDimz)] += result
                        else:
                            thread_time[(gridDimx+gridDimy+gridDimz+blockDimx+blockDimy+blockDimz)] = result
# Out:
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 1 1 1 Time: [1793.94, 1781.04]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 1 1 8 Time: [262.4, 262.269]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 1 4 1 Time: [507.294, 507.206]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 1 4 8 Time: [72.7454, 72.8546]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 8 1 1 Time: [262.395, 262.53]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 8 1 8 Time: [39.636, 39.879]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 8 4 1 Time: [73.1224, 73.1441]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 1 8 4 8 Time: [15.231, 14.83]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 1 1 1 Time: [131.253, 130.919]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 1 1 8 Time: [21.328, 20.0323]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 1 4 1 Time: [36.5308, 36.1059]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 1 4 8 Time: [8.14397, 8.01501]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 8 1 1 Time: [20.3212, 20.04]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 8 1 8 Time: [6.46259, 6.43594]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 8 4 1 Time: [8.55472, 9.03462]
# Command: main images/Chateau.png images/temp.png 1 256 1 1 1 16 8 4 8 Time: [7.52582, 7.70483]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 1 1 1 Time: [79.1404, 78.8986]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 1 1 8 Time: [12.6416, 12.6023]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 1 4 1 Time: [21.9849, 21.9836]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 1 4 8 Time: [5.7825, 5.81376]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 8 1 1 Time: [13.2359, 13.4833]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 8 1 8 Time: [5.22048, 5.33888]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 8 4 1 Time: [5.7945, 5.7487]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 1 8 4 8 Time: [6.3072, 6.47971]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 1 1 1 Time: [54.8337, 55.6303]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 1 1 8 Time: [9.43059, 9.42989]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 1 4 1 Time: [16.9332, 17.1331]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 1 4 8 Time: [5.56346, 5.68688]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 8 1 1 Time: [10.5492, 10.5552]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 8 1 8 Time: [5.85728, 6.04064]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 8 4 1 Time: [7.56378, 7.27066]
# Command: main images/Chateau.png images/temp.png 1 256 1 32 1 16 8 4 8 Time: [7.91536, 7.73661]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 1 1 1 Time: [53.1021, 52.9637]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 1 1 8 Time: [9.31398, 9.48701]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 1 4 1 Time: [15.8363, 15.9076]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 1 4 8 Time: [5.07402, 5.1225]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 8 1 1 Time: [9.3799, 9.84602]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 8 1 8 Time: [5.36413, 4.85491]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 8 4 1 Time: [4.87363, 4.88912]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 1 8 4 8 Time: [6.87936, 6.6023]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 1 1 1 Time: [63.2692, 63.5097]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 1 1 8 Time: [12.266, 12.3908]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 1 4 1 Time: [21.2301, 20.7932]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 1 4 8 Time: [8.75882, 8.94547]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 8 1 1 Time: [14.98, 14.762]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 8 1 8 Time: [9.19562, 8.86214]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 8 4 1 Time: [12.2579, 12.6305]
# Command: main images/Chateau.png images/temp.png 1 256 1 1024 1 16 8 4 8 Time: [18.897, 18.8263]

# %%
time_cpu = timeCapture("main images/Chateau.png images/temp.png 1 256 0", 5)

# %%
timeCapture("main images/Chateau.png images/temp.png 1 256 0", 5)
# Out:
# [216.023, 221.763, 187.915, 175.818, 172.742]

# %%
x_threads = []
y_times = []
for k, v in sorted(thread_time.items(), key = lambda x:x[0]):
    print(f"Total threads: {k}\nTime: {v}(mean: {np.mean(v)})")
    x_threads.append(k)
    y_times.append(np.mean(v))
# Out:
# Total threads: 0
# Time: [1793.94, 1781.04](mean: 1787.49)
# Total threads: 2
# Time: [507.294, 507.206](mean: 507.25)
# Total threads: 3
# Time: [262.4, 262.269, 262.395, 262.53](mean: 262.3985)
# Total threads: 4
# Time: [131.253, 130.919](mean: 131.086)
# Total threads: 5
# Time: [72.7454, 72.8546, 73.1224, 73.1441, 79.1404, 78.8986](mean: 74.98425)
# Total threads: 6
# Time: [39.636, 39.879, 36.5308, 36.1059](mean: 38.037925)
# Total threads: 7
# Time: [21.328, 20.0323, 20.3212, 20.04, 21.9849, 21.9836](mean: 20.94833333333333)
# Total threads: 8
# Time: [15.231, 14.83, 12.6416, 12.6023, 13.2359, 13.4833](mean: 13.670683333333335)
# Total threads: 9
# Time: [8.14397, 8.01501, 8.55472, 9.03462, 54.8337, 55.6303](mean: 24.035386666666668)
# Total threads: 10
# Time: [6.46259, 6.43594, 5.7825, 5.81376, 5.7945, 5.7487, 53.1021, 52.9637](mean: 17.76297375)
# Total threads: 11
# Time: [5.22048, 5.33888, 16.9332, 17.1331](mean: 11.156414999999999)
# Total threads: 12
# Time: [7.52582, 7.70483, 9.43059, 9.42989, 10.5492, 10.5552, 15.8363, 15.9076](mean: 10.86742875)
# Total threads: 13
# Time: [6.3072, 6.47971, 9.31398, 9.48701, 9.3799, 9.84602](mean: 8.468969999999999)
# Total threads: 14
# Time: [5.56346, 5.68688, 7.56378, 7.27066, 63.2692, 63.5097](mean: 25.477280000000004)
# Total threads: 15
# Time: [5.85728, 6.04064, 5.07402, 5.1225, 4.87363, 4.88912](mean: 5.309531666666666)
# Total threads: 16
# Time: [5.36413, 4.85491, 21.2301, 20.7932](mean: 13.060585)
# Total threads: 17
# Time: [7.91536, 7.73661, 12.266, 12.3908, 14.98, 14.762](mean: 11.675128333333333)
# Total threads: 18
# Time: [6.87936, 6.6023](mean: 6.74083)
# Total threads: 19
# Time: [8.75882, 8.94547, 12.2579, 12.6305](mean: 10.6481725)
# Total threads: 20
# Time: [9.19562, 8.86214](mean: 9.028880000000001)
# Total threads: 22
# Time: [18.897, 18.8263](mean: 18.861649999999997)

# %%
plt.plot(x_threads, y_times, color = 'red', label = "GPU")
plt.plot([0, max(x_threads)], [np.mean(time_cpu)]*2, color = "green", label = "CPU")
plt.plot([math.log2(961*640)]*2, [0, max(y_times)], color = 'blue', label = "Pixels")
plt.legend(loc="upper left")
plt.show()

# %%
times = 2
for gridDims in range(10, 2):
    for blockDims in range(10, 2):
        cmd = f"main images/Chateau.png images/temp.png 1 256 1 {2**gridDims} 1 1 {2**blockDims} 1 1"
        result = timeCapture(cmd, times)
        print(gridDims, blockDims, "Time:", np.mean(result))
# Out:
# 0 0 Time: [1788.9, 1780.7]
# 0 1 Time: [954.89, 954.588]
# 0 2 Time: [507.501, 507.17]
# 0 3 Time: [262.512, 262.35]
# 0 4 Time: [136.664, 136.729]
# 0 5 Time: [72.2963, 72.2538]
# 0 6 Time: [39.0919, 39.3001]
# 0 7 Time: [21.0942, 21.1446]
# 0 8 Time: [12.3896, 12.4534]
# 0 9 Time: [8.67414, 8.6279]
# 1 0 Time: [913.457, 914.218]
# 1 1 Time: [494.653, 494.793]
# 1 2 Time: [254.976, 254.763]
# 1 3 Time: [132.936, 132.995]
# 1 4 Time: [69.6739, 69.5382]
# 1 5 Time: [37.3686, 37.6548]
# 1 6 Time: [20.841, 20.7835]
# 1 7 Time: [11.8932, 11.7837]
# 1 8 Time: [7.5049, 7.57475]
# 1 9 Time: [5.85638, 5.86563]
# 2 0 Time: [473.043, 460.342]
# 2 1 Time: [250.656, 250.561]
# 2 2 Time: [134.363, 134.408]
# 2 3 Time: [70.2854, 70.3763]
# 2 4 Time: [37.4879, 37.529]
# 2 5 Time: [20.7304, 20.6756]
# 2 6 Time: [12.0313, 11.8524]
# 2 7 Time: [7.61581, 7.89654]
# 2 8 Time: [5.71606, 5.76541]
# 2 9 Time: [5.28262, 5.59155]
# 3 0 Time: [247.898, 247.987]
# 3 1 Time: [127.473, 127.531]
# 3 2 Time: [69.1589, 69.0237]
# 3 3 Time: [37.1135, 36.5328]
# 3 4 Time: [20.1099, 20.0941]
# 3 5 Time: [11.7554, 11.7597]
# 3 6 Time: [7.7615, 7.52438]
